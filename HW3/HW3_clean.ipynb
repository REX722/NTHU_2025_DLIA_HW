# %% [markdown]
# <div align="center">
#
# #### Lab 3
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 3: Anomaly Detection in Industrial Applications
#
# </div>

# %% [markdown]
# ### Introduction
#
# In today's industrial landscape, the ability to detect anomalies in manufacturing processes and products is critical for maintaining quality, efficiency, and safety. This lab focuses on leveraging deep learning techniques for anomaly detection in various industrial applications, using the MVTEC Anomaly Detection Dataset. By employing ImageNet-pretrained models available in torchvision, students will gain hands-on experience in classfying defects and irregularities across different types of industrial products.
#
# Throughout this lab, you'll be involved in the following key activities:
# - Explore and process the MVTec Anomaly Detection Dataset.
# - Apply ImageNet-pretrained models from [Torchvision](https://pytorch.org/vision/stable/models.html) to detect anomalies in industrial products.
# - Evaluate the performance of the models to understand their effectiveness in real-world industrial applications.
#
# ### Objectives
#
# - Understand the principles of anomaly detection in the context of industrial applications.
# - Learn how to implement and utilize ImageNet-pretrained models for detecting anomalies.
# - Analyze and interpret the results of the anomaly detection models to assess their practicality in industrial settings.
#
# ### Dataset
#
# The MVTec AD Dataset is a comprehensive collection of high-resolution images across different categories of industrial products, such as bottles, cables, and metal nuts, each with various types of defects. This dataset is pivotal for developing and benchmarking anomaly detection algorithms. You can download our lab's dataset [here](https://drive.google.com/file/d/19600hUOpx0hl78TdpdH0oyy-gGTk_F_o/view?usp=share_link). You can drop downloaded data and drop to colab, or you can put into yor google drive.
#
# ### References
# - [MVTec AD Dataset](https://www.kaggle.com/datasets/ipythonx/mvtec-ad/data) for the dataset used in this lab.
# - [Torchvision Models](https://pytorch.org/vision/stable/models.html) for accessing ImageNet-pretrained models to be used in anomaly detection tasks.
# - [State-of-the-Art Anomaly Detection on MVTec AD](https://paperswithcode.com/sota/anomaly-detection-on-mvtec-ad) for insights into the latest benchmarks and methodologies in anomaly detection applied to the MVTec AD dataset.
# - [CVPR 2019: MVTec AD — A Comprehensive Real-World Dataset for Unsupervised Anomaly Detection] for the original paper of MVTec AD dataset.

# %%
import glob
import matplotlib.pyplot as plt
import random
from tqdm.auto import tqdm
import cv2
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/drive')
# !tar -xvf /content/drive/MyDrive/Colab_Notebooks/深度學習HW3/cable.tar.gz cable
# Out:
# Mounted at /content/drive
# cable/
# cable/cable_swap/
# cable/cable_swap/004.png
# cable/cable_swap/009.png
# cable/cable_swap/005.png
# cable/cable_swap/002.png
# cable/cable_swap/001.png
# cable/cable_swap/000.png
# cable/cable_swap/008.png
# cable/cable_swap/010.png
# cable/cable_swap/011.png
# cable/cable_swap/006.png
# cable/cable_swap/003.png
# cable/cable_swap/007.png
# cable/.DS_Store
# cable/cut_inner_insulation/
# cable/cut_inner_insulation/004.png
# cable/cut_inner_insulation/009.png
# cable/cut_inner_insulation/005.png
# cable/cut_inner_insulation/002.png
# cable/cut_inner_insulation/001.png
# cable/cut_inner_insulation/012.png
# cable/cut_inner_insulation/000.png
# cable/cut_inner_insulation/008.png
# cable/cut_inner_insulation/010.png
# cable/cut_inner_insulation/013.png
# cable/cut_inner_insulation/011.png
# cable/cut_inner_insulation/006.png
# cable/cut_inner_insulation/003.png
# cable/cut_inner_insulation/007.png
# cable/cut_outer_insulation/
# cable/cut_outer_insulation/004.png
# cable/cut_outer_insulation/009.png
# cable/cut_outer_insulation/005.png
# cable/cut_outer_insulation/002.png
# cable/cut_outer_insulation/001.png
# cable/cut_outer_insulation/000.png
# cable/cut_outer_insulation/008.png
# cable/cut_outer_insulation/006.png
# cable/cut_outer_insulation/003.png
# cable/cut_outer_insulation/007.png
# cable/bent_wire/
# cable/bent_wire/004.png
# cable/bent_wire/009.png
# cable/bent_wire/.DS_Store
# cable/bent_wire/005.png
# cable/bent_wire/002.png
# cable/bent_wire/001.png
# cable/bent_wire/012.png
# cable/bent_wire/000.png
# cable/bent_wire/008.png
# cable/bent_wire/010.png
# cable/bent_wire/011.png
# cable/bent_wire/006.png
# cable/bent_wire/003.png
# cable/bent_wire/007.png
# cable/missing_cable/
# cable/missing_cable/004.png
# cable/missing_cable/009.png
# cable/missing_cable/005.png
# cable/missing_cable/002.png
# cable/missing_cable/001.png
# cable/missing_cable/000.png
# cable/missing_cable/008.png
# cable/missing_cable/010.png
# cable/missing_cable/011.png
# cable/missing_cable/006.png
# cable/missing_cable/003.png
# cable/missing_cable/007.png
# cable/good/
# cable/good/004.png
# cable/good/009.png
# cable/good/038.png
# cable/good/037.png
# cable/good/055.png
# cable/good/029.png
# cable/good/020.png
# cable/good/017.png
# cable/good/030.png
# cable/good/036.png
# cable/good/005.png
# cable/good/049.png
# cable/good/014.png
# cable/good/050.png
# cable/good/025.png
# cable/good/045.png
# cable/good/057.png
# cable/good/027.png
# cable/good/043.png
# cable/good/046.png
# cable/good/002.png
# cable/good/056.png
# cable/good/040.png
# cable/good/032.png
# cable/good/054.png
# cable/good/001.png
# cable/good/035.png
# cable/good/012.png
# cable/good/051.png
# cable/good/022.png
# cable/good/000.png
# cable/good/041.png
# cable/good/026.png
# cable/good/023.png
# cable/good/021.png
# cable/good/028.png
# cable/good/034.png
# cable/good/008.png
# cable/good/033.png
# cable/good/010.png
# cable/good/024.png
# cable/good/053.png
# cable/good/018.png
# cable/good/052.png
# cable/good/013.png
# cable/good/015.png
# cable/good/011.png
# cable/good/042.png
# cable/good/006.png
# cable/good/003.png
# cable/good/039.png
# cable/good/047.png
# cable/good/048.png
# cable/good/031.png
# cable/good/019.png
# cable/good/007.png
# cable/good/044.png
# cable/good/016.png
# cable/missing_wire/
# cable/missing_wire/004.png
# cable/missing_wire/009.png
# cable/missing_wire/005.png
# cable/missing_wire/002.png
# cable/missing_wire/001.png
# cable/missing_wire/000.png
# cable/missing_wire/008.png
# cable/missing_wire/006.png
# cable/missing_wire/003.png
# cable/missing_wire/007.png
# cable/poke_insulation/
# cable/poke_insulation/004.png
# cable/poke_insulation/009.png
# cable/poke_insulation/005.png
# cable/poke_insulation/002.png
# cable/poke_insulation/001.png
# cable/poke_insulation/000.png
# cable/poke_insulation/008.png
# cable/poke_insulation/006.png
# cable/poke_insulation/003.png
# cable/poke_insulation/007.png

# %%
file_paths = glob.glob('cable/*/*.png')
#file_paths = sorted([path for path in file_paths if path.split('/')[-1] in [f'{i:03}.png' for i in range(10)]])
file_paths = sorted([path for path in file_paths])
print(f'number of pictures:{len(file_paths)}')
# Out:
# number of pictures:139

# %%
from collections import Counter
import matplotlib.pyplot as plt

# 計算每個種類的照片有幾張
categories = [path.split('/')[-2] for path in file_paths]
category_counts = Counter(categories)

# Plotting the category counts
categories = sorted(list(category_counts.keys()))
counts = list(category_counts.values())

plt.figure(figsize=(10, 6))
bars = plt.bar(categories, counts)

for bar, count in zip(bars, counts):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
             str(count), ha='center', va='bottom', fontsize=10)

plt.xlabel('Category')
plt.ylabel('Number of Images')
plt.title('Number of Images per Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
all_data = []

for img in tqdm(file_paths):
    img = cv2.imread(img)
    img = img[..., ::-1]
    all_data.append(img)

all_data = np.stack(all_data)
print(all_data.shape)
# Out:
#   0%|          | 0/139 [00:00<?, ?it/s]
# (139, 1024, 1024, 3)

# %%
print(f'Classes: {categories}')

# 找到每個 Class 最開始的 index [0, 13, 25, 39....]
cumulative_counts = [0] + list(np.cumsum(list(category_counts.values())))

fig, axs = plt.subplots(len(categories), 2, figsize=(6, 4 * len(categories)))

for i, class_name in enumerate(categories):

    start_index = cumulative_counts[i]

    for j in range(2):
        axs[i, j].imshow(all_data[start_index + j])
        axs[i, j].axis('off')
        axs[i, j].set_title(f'{i+1}. {class_name}')

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## A. Data Loading and Preprocessing

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np

# Assuming category_counts is a Counter object containing image counts per category
# Example: category_counts = Counter({'category1': 15, 'category2': 12, 'category3': 18, ...})

x_train = []
x_val = []
y_train = []
y_val = []

# Cumulative count to track image indices across categories
cumulative_count = 0

for category_index, (category_name, image_count) in enumerate(category_counts.items()):
    # Calculate split indices for this category
    train_images_per_class = int(image_count * 0.8)
    val_images_per_class = image_count - train_images_per_class

    # Extract images for this category
    category_images = all_data[cumulative_count : cumulative_count + image_count]

    # Split into train and validation
    x_train.extend(category_images[:train_images_per_class])
    x_val.extend(category_images[train_images_per_class:])

    # Create labels for this category
    y_train.extend([category_index] * train_images_per_class)
    y_val.extend([category_index] * val_images_per_class)

    # Update cumulative count for the next category
    cumulative_count += image_count

# Convert to NumPy arrays and transpose
x_train = np.transpose(np.array(x_train), (0, 3, 1, 2))
x_val = np.transpose(np.array(x_val), (0, 3, 1, 2))
y_train = np.array(y_train)
y_val = np.array(y_val)

print(f'Shape of x_train: {x_train.shape}')
print(f'Shape of x_val: {x_val.shape}')
print(f'Shape of y_train: {y_train.shape}')
print(f'Shape of y_val: {y_val.shape}')
# Out:
# Shape of x_train: (109, 3, 1024, 1024)
# Shape of x_val: (30, 3, 1024, 1024)
# Shape of y_train: (109,)
# Shape of y_val: (30,)

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image

train_transforms = transforms.Compose(
    [
        transforms.Resize((224, 224)),
        transforms.AutoAugment(),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]
)

val_transforms = transforms.Compose(
    [
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
    ]
)

class MyDataset(Dataset):
    def __init__(self, x, y, transform=None):
        self.x = x
        self.y = torch.from_numpy(y).long()
        self.transform = transform

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        new_x = np.transpose(self.x[idx], (1, 2, 0))
        return self.transform(Image.fromarray(new_x)), self.y[idx]

# %%
batch_size = 8

train_dataset = MyDataset(x_train, y_train, train_transforms)
val_dataset = MyDataset(x_val, y_val, val_transforms)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True, persistent_workers=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=1, pin_memory=True, persistent_workers=True)

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models

model = models.resnet18(weights='IMAGENET1K_V1')

# ConvNet as fixed feature extractor (freeze parameters)
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features
num_class = 8

# change # of class from 1000 into 8 in the last layer
model.fc = nn.Linear(num_ftrs, num_class)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=8, bias=True)
# )

# %%
import torch.nn as nn
from torchvision import models

# 載入 MobileNetV2 預訓練模型
model = models.mobilenet_v2(weights='IMAGENET1K_V1')

# Freeze 所有參數（不進行訓練）
for param in model.parameters():
    param.requires_grad = False

# 修改最後分類層：將原本 1000 類改為 8 類
num_ftrs = model.classifier[1].in_features
num_class = 8
model.classifier[1] = nn.Linear(num_ftrs, num_class)

print(model)
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=8, bias=True)
#   )
# )

# %% [markdown]
# ## C. Training the Neural Network

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from tqdm.auto import tqdm

# 記錄用
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# 訓練設定
epochs = 75
model = model.cuda()
best_val_loss = float('inf')
best_val_acc = -1

# 損失函數 & optimizer & scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-2)

# 使用 ReduceLROnPlateau：根據 val loss 沒進步自動降低 LR
lr_scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)

for epoch in tqdm(range(epochs)):
    # === Training ===
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for images, labels in train_loader:
        images = images.cuda()
        images = images / 255.  # normalize to [0, 1]
        labels = labels.cuda().long()

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted == labels).sum().item()
        total_train_samples += labels.size(0)

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # === Validation ===
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            images = images / 255.
            labels = labels.cuda().long()
            outputs = model(images)

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # 更新 learning rate（根據 val loss）
    lr_scheduler.step(avg_val_loss)

    # 儲存最佳模型
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    # 印出結果
    print(f'Epoch {epoch+1}/{epochs}, '
          f'Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.2f}%, '
          f'Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.2f}%, '
          f'Best Val loss: {best_val_loss:.4f}, Best Val acc: {best_val_acc:.2f}%')

    # 紀錄數據
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/75 [00:00<?, ?it/s]
# Epoch 1/75, Train loss: 7.0104, Train acc: 19.27%, Val loss: 3.9254, Val acc: 40.00%, Best Val loss: 3.9254, Best Val acc: 40.00%
# Epoch 2/75, Train loss: 4.0337, Train acc: 34.86%, Val loss: 3.4127, Val acc: 40.00%, Best Val loss: 3.4127, Best Val acc: 40.00%
# Epoch 3/75, Train loss: 2.3695, Train acc: 41.28%, Val loss: 3.9957, Val acc: 10.00%, Best Val loss: 3.4127, Best Val acc: 40.00%
# Epoch 4/75, Train loss: 1.9309, Train acc: 42.20%, Val loss: 4.1418, Val acc: 40.00%, Best Val loss: 3.4127, Best Val acc: 40.00%
# Epoch 5/75, Train loss: 1.5922, Train acc: 58.72%, Val loss: 2.8089, Val acc: 40.00%, Best Val loss: 2.8089, Best Val acc: 40.00%
# Epoch 6/75, Train loss: 2.0500, Train acc: 47.71%, Val loss: 4.4798, Val acc: 43.33%, Best Val loss: 2.8089, Best Val acc: 43.33%
# Epoch 7/75, Train loss: 1.6527, Train acc: 58.72%, Val loss: 2.7663, Val acc: 36.67%, Best Val loss: 2.7663, Best Val acc: 43.33%
# Epoch 8/75, Train loss: 1.6835, Train acc: 59.63%, Val loss: 2.1195, Val acc: 33.33%, Best Val loss: 2.1195, Best Val acc: 43.33%
# Epoch 9/75, Train loss: 1.7996, Train acc: 52.29%, Val loss: 1.5864, Val acc: 63.33%, Best Val loss: 1.5864, Best Val acc: 63.33%
# Epoch 10/75, Train loss: 1.8820, Train acc: 60.55%, Val loss: 2.0833, Val acc: 40.00%, Best Val loss: 1.5864, Best Val acc: 63.33%
# Epoch 11/75, Train loss: 1.1682, Train acc: 70.64%, Val loss: 1.7874, Val acc: 56.67%, Best Val loss: 1.5864, Best Val acc: 63.33%
# Epoch 12/75, Train loss: 1.4892, Train acc: 58.72%, Val loss: 2.0478, Val acc: 43.33%, Best Val loss: 1.5864, Best Val acc: 63.33%
# Epoch 13/75, Train loss: 1.7429, Train acc: 62.39%, Val loss: 1.9687, Val acc: 46.67%, Best Val loss: 1.5864, Best Val acc: 63.33%
# Epoch 14/75, Train loss: 1.6921, Train acc: 60.55%, Val loss: 1.5239, Val acc: 70.00%, Best Val loss: 1.5239, Best Val acc: 70.00%
# Epoch 15/75, Train loss: 2.1556, Train acc: 47.71%, Val loss: 2.6580, Val acc: 60.00%, Best Val loss: 1.5239, Best Val acc: 70.00%
# Epoch 16/75, Train loss: 1.9626, Train acc: 55.05%, Val loss: 2.5638, Val acc: 53.33%, Best Val loss: 1.5239, Best Val acc: 70.00%
# Epoch 17/75, Train loss: 1.7321, Train acc: 56.88%, Val loss: 1.6542, Val acc: 66.67%, Best Val loss: 1.5239, Best Val acc: 70.00%
# Epoch 18/75, Train loss: 1.8739, Train acc: 65.14%, Val loss: 1.6547, Val acc: 66.67%, Best Val loss: 1.5239, Best Val acc: 70.00%
# Epoch 19/75, Train loss: 1.3995, Train acc: 70.64%, Val loss: 1.9646, Val acc: 63.33%, Best Val loss: 1.5239, Best Val acc: 70.00%
# Epoch 20/75, Train loss: 0.9427, Train acc: 74.31%, Val loss: 1.9186, Val acc: 43.33%, Best Val loss: 1.5239, Best Val acc: 70.00%
# Epoch 21/75, Train loss: 0.9955, Train acc: 72.48%, Val loss: 1.3821, Val acc: 66.67%, Best Val loss: 1.3821, Best Val acc: 70.00%
# Epoch 22/75, Train loss: 0.9172, Train acc: 71.56%, Val loss: 1.3954, Val acc: 60.00%, Best Val loss: 1.3821, Best Val acc: 70.00%
# Epoch 23/75, Train loss: 0.9946, Train acc: 69.72%, Val loss: 1.1986, Val acc: 70.00%, Best Val loss: 1.1986, Best Val acc: 70.00%
# Epoch 24/75, Train loss: 0.7712, Train acc: 78.90%, Val loss: 1.4744, Val acc: 63.33%, Best Val loss: 1.1986, Best Val acc: 70.00%
# Epoch 25/75, Train loss: 1.0007, Train acc: 71.56%, Val loss: 1.4298, Val acc: 56.67%, Best Val loss: 1.1986, Best Val acc: 70.00%
# Epoch 26/75, Train loss: 1.0388, Train acc: 66.97%, Val loss: 1.2591, Val acc: 63.33%, Best Val loss: 1.1986, Best Val acc: 70.00%
# Epoch 27/75, Train loss: 0.5127, Train acc: 83.49%, Val loss: 1.3420, Val acc: 60.00%, Best Val loss: 1.1986, Best Val acc: 70.00%
# Epoch 28/75, Train loss: 0.4693, Train acc: 83.49%, Val loss: 1.2099, Val acc: 63.33%, Best Val loss: 1.1986, Best Val acc: 70.00%
# Epoch 29/75, Train loss: 0.9616, Train acc: 78.90%, Val loss: 1.6948, Val acc: 66.67%, Best Val loss: 1.1986, Best Val acc: 70.00%
# Epoch 30/75, Train loss: 0.5664, Train acc: 78.90%, Val loss: 1.1894, Val acc: 70.00%, Best Val loss: 1.1894, Best Val acc: 70.00%
# Epoch 31/75, Train loss: 0.6932, Train acc: 77.06%, Val loss: 1.2554, Val acc: 70.00%, Best Val loss: 1.1894, Best Val acc: 70.00%
# Epoch 32/75, Train loss: 0.6567, Train acc: 80.73%, Val loss: 1.2786, Val acc: 70.00%, Best Val loss: 1.1894, Best Val acc: 70.00%
# Epoch 33/75, Train loss: 0.5603, Train acc: 82.57%, Val loss: 1.3004, Val acc: 53.33%, Best Val loss: 1.1894, Best Val acc: 70.00%
# Epoch 34/75, Train loss: 0.6205, Train acc: 79.82%, Val loss: 1.1666, Val acc: 60.00%, Best Val loss: 1.1666, Best Val acc: 70.00%
# Epoch 35/75, Train loss: 0.6287, Train acc: 77.98%, Val loss: 1.4024, Val acc: 60.00%, Best Val loss: 1.1666, Best Val acc: 70.00%
# Epoch 36/75, Train loss: 0.5955, Train acc: 81.65%, Val loss: 1.2912, Val acc: 73.33%, Best Val loss: 1.1666, Best Val acc: 73.33%
# Epoch 37/75, Train loss: 0.7738, Train acc: 77.06%, Val loss: 1.1614, Val acc: 66.67%, Best Val loss: 1.1614, Best Val acc: 73.33%
# Epoch 38/75, Train loss: 0.7359, Train acc: 77.98%, Val loss: 1.2124, Val acc: 66.67%, Best Val loss: 1.1614, Best Val acc: 73.33%
# Epoch 39/75, Train loss: 0.9921, Train acc: 75.23%, Val loss: 1.1459, Val acc: 63.33%, Best Val loss: 1.1459, Best Val acc: 73.33%
# Epoch 40/75, Train loss: 0.4878, Train acc: 85.32%, Val loss: 1.2637, Val acc: 63.33%, Best Val loss: 1.1459, Best Val acc: 73.33%
# Epoch 41/75, Train loss: 0.9249, Train acc: 74.31%, Val loss: 1.1642, Val acc: 66.67%, Best Val loss: 1.1459, Best Val acc: 73.33%
# Epoch 42/75, Train loss: 0.8203, Train acc: 77.06%, Val loss: 1.1382, Val acc: 63.33%, Best Val loss: 1.1382, Best Val acc: 73.33%
# Epoch 43/75, Train loss: 0.6779, Train acc: 79.82%, Val loss: 1.1334, Val acc: 63.33%, Best Val loss: 1.1334, Best Val acc: 73.33%
# Epoch 44/75, Train loss: 0.6516, Train acc: 79.82%, Val loss: 1.1825, Val acc: 70.00%, Best Val loss: 1.1334, Best Val acc: 73.33%
# Epoch 45/75, Train loss: 0.8695, Train acc: 74.31%, Val loss: 1.1140, Val acc: 70.00%, Best Val loss: 1.1140, Best Val acc: 73.33%
# Epoch 46/75, Train loss: 0.7404, Train acc: 77.06%, Val loss: 1.1876, Val acc: 66.67%, Best Val loss: 1.1140, Best Val acc: 73.33%
# Epoch 47/75, Train loss: 0.7960, Train acc: 77.06%, Val loss: 0.9775, Val acc: 60.00%, Best Val loss: 0.9775, Best Val acc: 73.33%
# Epoch 48/75, Train loss: 0.8298, Train acc: 77.98%, Val loss: 1.2843, Val acc: 66.67%, Best Val loss: 0.9775, Best Val acc: 73.33%
# Epoch 49/75, Train loss: 0.5440, Train acc: 83.49%, Val loss: 1.0043, Val acc: 63.33%, Best Val loss: 0.9775, Best Val acc: 73.33%
# Epoch 50/75, Train loss: 0.9417, Train acc: 71.56%, Val loss: 1.2935, Val acc: 60.00%, Best Val loss: 0.9775, Best Val acc: 73.33%
# Epoch 51/75, Train loss: 0.5615, Train acc: 82.57%, Val loss: 1.3647, Val acc: 70.00%, Best Val loss: 0.9775, Best Val acc: 73.33%
# Epoch 52/75, Train loss: 0.7829, Train acc: 80.73%, Val loss: 1.1288, Val acc: 63.33%, Best Val loss: 0.9775, Best Val acc: 73.33%
# Epoch 53/75, Train loss: 0.7242, Train acc: 77.98%, Val loss: 1.0527, Val acc: 63.33%, Best Val loss: 0.9775, Best Val acc: 73.33%
# Epoch 54/75, Train loss: 0.5531, Train acc: 82.57%, Val loss: 0.9421, Val acc: 70.00%, Best Val loss: 0.9421, Best Val acc: 73.33%
# Epoch 55/75, Train loss: 0.6192, Train acc: 79.82%, Val loss: 1.0182, Val acc: 66.67%, Best Val loss: 0.9421, Best Val acc: 73.33%
# Epoch 56/75, Train loss: 0.5116, Train acc: 84.40%, Val loss: 1.2474, Val acc: 63.33%, Best Val loss: 0.9421, Best Val acc: 73.33%
# Epoch 57/75, Train loss: 0.6444, Train acc: 79.82%, Val loss: 1.0668, Val acc: 63.33%, Best Val loss: 0.9421, Best Val acc: 73.33%
# Epoch 58/75, Train loss: 0.4238, Train acc: 88.99%, Val loss: 1.1225, Val acc: 63.33%, Best Val loss: 0.9421, Best Val acc: 73.33%
# Epoch 59/75, Train loss: 0.4621, Train acc: 83.49%, Val loss: 0.9830, Val acc: 73.33%, Best Val loss: 0.9421, Best Val acc: 73.33%
# Epoch 60/75, Train loss: 0.4115, Train acc: 81.65%, Val loss: 0.8598, Val acc: 70.00%, Best Val loss: 0.8598, Best Val acc: 73.33%
# Epoch 61/75, Train loss: 0.5030, Train acc: 84.40%, Val loss: 1.0545, Val acc: 66.67%, Best Val loss: 0.8598, Best Val acc: 73.33%
# Epoch 62/75, Train loss: 0.6328, Train acc: 85.32%, Val loss: 1.0656, Val acc: 60.00%, Best Val loss: 0.8598, Best Val acc: 73.33%
# Epoch 63/75, Train loss: 0.6858, Train acc: 78.90%, Val loss: 1.0578, Val acc: 66.67%, Best Val loss: 0.8598, Best Val acc: 73.33%
# Epoch 64/75, Train loss: 0.5732, Train acc: 84.40%, Val loss: 0.8888, Val acc: 70.00%, Best Val loss: 0.8598, Best Val acc: 73.33%
# Epoch 65/75, Train loss: 0.7658, Train acc: 78.90%, Val loss: 0.9744, Val acc: 70.00%, Best Val loss: 0.8598, Best Val acc: 73.33%
# Epoch 66/75, Train loss: 0.6594, Train acc: 78.90%, Val loss: 0.8422, Val acc: 73.33%, Best Val loss: 0.8422, Best Val acc: 73.33%
# Epoch 67/75, Train loss: 0.6060, Train acc: 82.57%, Val loss: 0.9063, Val acc: 70.00%, Best Val loss: 0.8422, Best Val acc: 73.33%
# Epoch 68/75, Train loss: 0.4368, Train acc: 84.40%, Val loss: 0.9849, Val acc: 70.00%, Best Val loss: 0.8422, Best Val acc: 73.33%
# Epoch 69/75, Train loss: 0.6169, Train acc: 81.65%, Val loss: 0.8214, Val acc: 66.67%, Best Val loss: 0.8214, Best Val acc: 73.33%
# Epoch 70/75, Train loss: 0.5803, Train acc: 76.15%, Val loss: 1.0093, Val acc: 70.00%, Best Val loss: 0.8214, Best Val acc: 73.33%
# Epoch 71/75, Train loss: 0.4785, Train acc: 80.73%, Val loss: 0.9828, Val acc: 70.00%, Best Val loss: 0.8214, Best Val acc: 73.33%
# Epoch 72/75, Train loss: 0.5748, Train acc: 80.73%, Val loss: 0.8311, Val acc: 76.67%, Best Val loss: 0.8214, Best Val acc: 76.67%
# Epoch 73/75, Train loss: 0.5236, Train acc: 83.49%, Val loss: 1.0263, Val acc: 63.33%, Best Val loss: 0.8214, Best Val acc: 76.67%
# Epoch 74/75, Train loss: 0.6347, Train acc: 77.98%, Val loss: 0.8848, Val acc: 66.67%, Best Val loss: 0.8214, Best Val acc: 76.67%
# Epoch 75/75, Train loss: 0.4444, Train acc: 86.24%, Val loss: 1.0296, Val acc: 70.00%, Best Val loss: 0.8214, Best Val acc: 76.67%

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 75
model = model.cuda()

best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.CrossEntropyLoss() #通常用於分類任務
optimizer = optim.Adam(model.parameters(), lr=1e-2)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=len(train_loader)*epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for images, labels in train_loader:
        images = images.cuda()
        images = (images) / 255.#將資料的範圍變成0到1
        labels = labels.cuda()
        optimizer.zero_grad()
        outputs = model(images)

        labels = labels.long()

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted == labels).sum().item()
        total_train_samples += labels.size(0)

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            images = (images) / 255.
            labels = labels.cuda()
            outputs = model(images)

            labels = labels.long()

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Learning rate update
    lr_scheduler.step()

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 3.6752, Train acc: 28.4404%, Val loss: 2.4078, Val acc: 10.0000%, Best Val loss: 2.4078 Best Val acc: 10.00%
# Epoch 2/100, Train loss: 2.2131, Train acc: 41.2844%, Val loss: 2.8154, Val acc: 10.0000%, Best Val loss: 2.4078 Best Val acc: 10.00%
# Epoch 3/100, Train loss: 1.6823, Train acc: 51.3761%, Val loss: 2.9325, Val acc: 10.0000%, Best Val loss: 2.4078 Best Val acc: 10.00%
# Epoch 4/100, Train loss: 2.0703, Train acc: 46.7890%, Val loss: 2.9489, Val acc: 16.6667%, Best Val loss: 2.4078 Best Val acc: 16.67%
# Epoch 5/100, Train loss: 1.5981, Train acc: 52.2936%, Val loss: 3.4613, Val acc: 40.0000%, Best Val loss: 2.4078 Best Val acc: 40.00%
# Epoch 6/100, Train loss: 2.0500, Train acc: 46.7890%, Val loss: 3.3947, Val acc: 30.0000%, Best Val loss: 2.4078 Best Val acc: 40.00%
# Epoch 7/100, Train loss: 1.7213, Train acc: 53.2110%, Val loss: 3.4720, Val acc: 23.3333%, Best Val loss: 2.4078 Best Val acc: 40.00%
# Epoch 8/100, Train loss: 1.6129, Train acc: 65.1376%, Val loss: 2.5519, Val acc: 33.3333%, Best Val loss: 2.4078 Best Val acc: 40.00%
# Epoch 9/100, Train loss: 1.0184, Train acc: 69.7248%, Val loss: 1.5515, Val acc: 50.0000%, Best Val loss: 1.5515 Best Val acc: 50.00%
# Epoch 10/100, Train loss: 1.1856, Train acc: 67.8899%, Val loss: 1.4667, Val acc: 43.3333%, Best Val loss: 1.4667 Best Val acc: 50.00%
# Epoch 11/100, Train loss: 1.2547, Train acc: 63.3028%, Val loss: 0.7891, Val acc: 76.6667%, Best Val loss: 0.7891 Best Val acc: 76.67%
# Epoch 12/100, Train loss: 1.3289, Train acc: 58.7156%, Val loss: 0.7999, Val acc: 70.0000%, Best Val loss: 0.7891 Best Val acc: 76.67%
# Epoch 13/100, Train loss: 0.9264, Train acc: 69.7248%, Val loss: 0.8476, Val acc: 76.6667%, Best Val loss: 0.7891 Best Val acc: 76.67%
# Epoch 14/100, Train loss: 1.2123, Train acc: 60.5505%, Val loss: 0.8988, Val acc: 73.3333%, Best Val loss: 0.7891 Best Val acc: 76.67%
# Epoch 15/100, Train loss: 1.0794, Train acc: 65.1376%, Val loss: 0.8390, Val acc: 56.6667%, Best Val loss: 0.7891 Best Val acc: 76.67%
# Epoch 16/100, Train loss: 1.2659, Train acc: 63.3028%, Val loss: 0.6264, Val acc: 80.0000%, Best Val loss: 0.6264 Best Val acc: 80.00%
# Epoch 17/100, Train loss: 1.0156, Train acc: 73.3945%, Val loss: 1.1398, Val acc: 63.3333%, Best Val loss: 0.6264 Best Val acc: 80.00%
# Epoch 18/100, Train loss: 0.8728, Train acc: 74.3119%, Val loss: 0.5893, Val acc: 80.0000%, Best Val loss: 0.5893 Best Val acc: 80.00%
# Epoch 19/100, Train loss: 0.7784, Train acc: 77.0642%, Val loss: 0.7029, Val acc: 73.3333%, Best Val loss: 0.5893 Best Val acc: 80.00%
# Epoch 20/100, Train loss: 1.2356, Train acc: 72.4771%, Val loss: 0.6684, Val acc: 70.0000%, Best Val loss: 0.5893 Best Val acc: 80.00%
# Epoch 21/100, Train loss: 0.8872, Train acc: 67.8899%, Val loss: 0.5511, Val acc: 83.3333%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 22/100, Train loss: 1.0095, Train acc: 70.6422%, Val loss: 0.6226, Val acc: 83.3333%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 23/100, Train loss: 1.3406, Train acc: 64.2202%, Val loss: 0.7447, Val acc: 76.6667%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 24/100, Train loss: 1.3857, Train acc: 55.0459%, Val loss: 0.7185, Val acc: 80.0000%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 25/100, Train loss: 1.1857, Train acc: 74.3119%, Val loss: 0.8549, Val acc: 76.6667%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 26/100, Train loss: 0.7219, Train acc: 77.9817%, Val loss: 1.0371, Val acc: 73.3333%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 27/100, Train loss: 0.9114, Train acc: 74.3119%, Val loss: 0.8529, Val acc: 80.0000%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 28/100, Train loss: 0.9641, Train acc: 69.7248%, Val loss: 0.7202, Val acc: 76.6667%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 29/100, Train loss: 1.0720, Train acc: 66.9725%, Val loss: 0.9272, Val acc: 73.3333%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 30/100, Train loss: 1.2693, Train acc: 67.8899%, Val loss: 0.9631, Val acc: 70.0000%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 31/100, Train loss: 0.9330, Train acc: 78.8991%, Val loss: 0.8471, Val acc: 73.3333%, Best Val loss: 0.5511 Best Val acc: 83.33%
# Epoch 32/100, Train loss: 0.7240, Train acc: 77.0642%, Val loss: 0.5496, Val acc: 86.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 33/100, Train loss: 0.7248, Train acc: 79.8165%, Val loss: 0.9006, Val acc: 83.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 34/100, Train loss: 1.0337, Train acc: 73.3945%, Val loss: 0.9920, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 35/100, Train loss: 0.8058, Train acc: 76.1468%, Val loss: 1.3617, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 36/100, Train loss: 0.7396, Train acc: 77.0642%, Val loss: 0.7309, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 37/100, Train loss: 0.8544, Train acc: 75.2294%, Val loss: 1.3156, Val acc: 53.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 38/100, Train loss: 1.5006, Train acc: 70.6422%, Val loss: 0.9824, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 39/100, Train loss: 1.4503, Train acc: 65.1376%, Val loss: 0.8185, Val acc: 70.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 40/100, Train loss: 0.9785, Train acc: 68.8073%, Val loss: 0.8048, Val acc: 70.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 41/100, Train loss: 1.0856, Train acc: 67.8899%, Val loss: 0.7526, Val acc: 80.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 42/100, Train loss: 0.9906, Train acc: 77.9817%, Val loss: 0.6521, Val acc: 70.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 43/100, Train loss: 0.8900, Train acc: 69.7248%, Val loss: 1.4303, Val acc: 60.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 44/100, Train loss: 1.5978, Train acc: 68.8073%, Val loss: 1.3968, Val acc: 56.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 45/100, Train loss: 1.2005, Train acc: 72.4771%, Val loss: 1.1667, Val acc: 63.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 46/100, Train loss: 0.8262, Train acc: 77.9817%, Val loss: 0.8242, Val acc: 83.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 47/100, Train loss: 0.7816, Train acc: 79.8165%, Val loss: 0.5667, Val acc: 80.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 48/100, Train loss: 0.7697, Train acc: 77.9817%, Val loss: 0.6494, Val acc: 83.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 49/100, Train loss: 0.8722, Train acc: 69.7248%, Val loss: 0.8423, Val acc: 70.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 50/100, Train loss: 0.7545, Train acc: 81.6514%, Val loss: 0.8955, Val acc: 66.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 51/100, Train loss: 0.8884, Train acc: 77.0642%, Val loss: 0.8675, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 52/100, Train loss: 1.3434, Train acc: 67.8899%, Val loss: 1.3986, Val acc: 70.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 53/100, Train loss: 0.7096, Train acc: 75.2294%, Val loss: 0.6373, Val acc: 83.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 54/100, Train loss: 1.2273, Train acc: 66.0550%, Val loss: 1.0901, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 55/100, Train loss: 1.0213, Train acc: 73.3945%, Val loss: 0.7796, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 56/100, Train loss: 0.5010, Train acc: 88.0734%, Val loss: 0.7969, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 57/100, Train loss: 0.6749, Train acc: 77.9817%, Val loss: 1.1898, Val acc: 60.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 58/100, Train loss: 0.8954, Train acc: 74.3119%, Val loss: 1.1778, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 59/100, Train loss: 0.7178, Train acc: 77.0642%, Val loss: 0.7178, Val acc: 80.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 60/100, Train loss: 0.6699, Train acc: 77.9817%, Val loss: 0.8676, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 61/100, Train loss: 0.6449, Train acc: 79.8165%, Val loss: 0.8423, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 62/100, Train loss: 0.7399, Train acc: 79.8165%, Val loss: 0.7819, Val acc: 83.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 63/100, Train loss: 0.7460, Train acc: 77.9817%, Val loss: 1.0779, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 64/100, Train loss: 0.8575, Train acc: 78.8991%, Val loss: 1.0382, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 65/100, Train loss: 0.8212, Train acc: 75.2294%, Val loss: 1.1076, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 66/100, Train loss: 0.9998, Train acc: 70.6422%, Val loss: 0.8256, Val acc: 83.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 67/100, Train loss: 0.5824, Train acc: 82.5688%, Val loss: 0.7271, Val acc: 70.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 68/100, Train loss: 0.5582, Train acc: 81.6514%, Val loss: 0.6641, Val acc: 80.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 69/100, Train loss: 0.3749, Train acc: 87.1560%, Val loss: 1.0540, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 70/100, Train loss: 0.7552, Train acc: 76.1468%, Val loss: 0.8846, Val acc: 66.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 71/100, Train loss: 0.8906, Train acc: 77.0642%, Val loss: 0.9858, Val acc: 83.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 72/100, Train loss: 0.7294, Train acc: 79.8165%, Val loss: 1.0385, Val acc: 70.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 73/100, Train loss: 0.4620, Train acc: 86.2385%, Val loss: 0.7060, Val acc: 86.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 74/100, Train loss: 0.9756, Train acc: 76.1468%, Val loss: 0.9040, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 75/100, Train loss: 0.3573, Train acc: 88.9908%, Val loss: 0.9608, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 76/100, Train loss: 0.8967, Train acc: 71.5596%, Val loss: 0.7472, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 77/100, Train loss: 0.5593, Train acc: 85.3211%, Val loss: 0.6899, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 78/100, Train loss: 1.0380, Train acc: 73.3945%, Val loss: 1.9217, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 79/100, Train loss: 1.5202, Train acc: 67.8899%, Val loss: 1.1908, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 80/100, Train loss: 0.9125, Train acc: 77.9817%, Val loss: 1.5682, Val acc: 63.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 81/100, Train loss: 0.8334, Train acc: 73.3945%, Val loss: 1.2711, Val acc: 70.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 82/100, Train loss: 1.2078, Train acc: 79.8165%, Val loss: 1.4305, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 83/100, Train loss: 1.5725, Train acc: 66.9725%, Val loss: 2.0150, Val acc: 56.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 84/100, Train loss: 1.2973, Train acc: 65.1376%, Val loss: 1.3770, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 85/100, Train loss: 0.8785, Train acc: 82.5688%, Val loss: 1.0370, Val acc: 83.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 86/100, Train loss: 0.9198, Train acc: 74.3119%, Val loss: 1.3888, Val acc: 63.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 87/100, Train loss: 1.0695, Train acc: 74.3119%, Val loss: 1.1563, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 88/100, Train loss: 0.8419, Train acc: 77.0642%, Val loss: 0.8779, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 89/100, Train loss: 0.5617, Train acc: 85.3211%, Val loss: 1.2317, Val acc: 73.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 90/100, Train loss: 0.8449, Train acc: 73.3945%, Val loss: 0.9901, Val acc: 66.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 91/100, Train loss: 0.6784, Train acc: 80.7339%, Val loss: 0.8680, Val acc: 80.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 92/100, Train loss: 0.9419, Train acc: 78.8991%, Val loss: 1.3264, Val acc: 63.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 93/100, Train loss: 1.3456, Train acc: 69.7248%, Val loss: 1.9101, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 94/100, Train loss: 0.9654, Train acc: 77.0642%, Val loss: 1.2515, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 95/100, Train loss: 0.8790, Train acc: 80.7339%, Val loss: 0.8841, Val acc: 70.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 96/100, Train loss: 1.3117, Train acc: 71.5596%, Val loss: 1.5577, Val acc: 53.3333%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 97/100, Train loss: 0.9319, Train acc: 77.9817%, Val loss: 1.0141, Val acc: 76.6667%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 98/100, Train loss: 1.0601, Train acc: 74.3119%, Val loss: 1.1844, Val acc: 70.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 99/100, Train loss: 0.9229, Train acc: 77.0642%, Val loss: 0.9318, Val acc: 80.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%
# Epoch 100/100, Train loss: 0.8900, Train acc: 83.4862%, Val loss: 0.9577, Val acc: 80.0000%, Best Val loss: 0.5496 Best Val acc: 86.67%

# %% [markdown]
# ### Visualizing model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %% [markdown]
# ### Load Trained Model and Evaluate

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():
    for images, labels in val_loader:

        images = images.cuda()
        images = (images) / 255.

        labels = labels.cuda()
        labels = labels.long()

        outputs = model(images)

        predicted = outputs.argmax(-1)
        print(predicted)
        print(labels)
        test_correct += (predicted == labels).sum().item()
        test_total += labels.size(0)

print(f'Test accuracy is {100. * test_correct / test_total}%')
# Out:
# tensor([0, 0, 0, 1, 4, 1, 4, 2], device='cuda:0')
# tensor([0, 0, 0, 1, 1, 1, 2, 2], device='cuda:0')
# tensor([2, 3, 3, 4, 4, 4, 4, 4], device='cuda:0')
# tensor([2, 3, 3, 4, 4, 4, 4, 4], device='cuda:0')
# tensor([2, 4, 4, 4, 4, 4, 4, 5], device='cuda:0')
# tensor([4, 4, 4, 4, 4, 4, 4, 5], device='cuda:0')
# tensor([5, 5, 6, 6, 7, 4], device='cuda:0')
# tensor([5, 5, 6, 6, 7, 7], device='cuda:0')
# Test accuracy is 86.66666666666667%
